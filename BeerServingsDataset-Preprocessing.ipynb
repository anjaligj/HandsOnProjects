# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='http://bit.ly/drinksbycountry'

# %%
pd.read_table(url)
# Out:
#     country,beer_servings,spirit_servings,wine_servings,total_litres_of_pure_alcohol,continent
# 0                           Afghanistan,0,0,0,0.0,Asia
# 1                         Albania,89,132,54,4.9,Europe
# 2                           Algeria,25,0,14,0.7,Africa
# 3                      Andorra,245,138,312,12.4,Europe
# 4                          Angola,217,57,45,5.9,Africa
# ..                                                 ...
# 188              Venezuela,333,100,3,7.7,South America
# 189                           Vietnam,111,2,1,2.0,Asia
# 190                               Yemen,6,0,0,0.1,Asia
# 191                          Zambia,32,19,4,2.5,Africa
# 192                        Zimbabwe,64,18,4,4.7,Africa
#
# [193 rows x 1 columns]

# %%
pd.read_table(url,sep=',')
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
data=pd.read_csv('beer-servings.csv')
data
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
data1=pd.read_csv('beer-servings.csv',index_col='Unnamed: 0')
data1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela            NaN            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
#For retaining the data even after refresh runtimes
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d09b09a4-e5fc-45d8-8882-edf87f312bdf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d09b09a4-e5fc-45d8-8882-edf87f312bdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv('beer-servings.csv',index_col='Unnamed: 0')
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela            NaN            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
data.shape
# Out:
# (193, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 185 non-null    float64
#  2   spirit_servings               185 non-null    float64
#  3   wine_servings                 187 non-null    float64
#  4   total_litres_of_pure_alcohol  192 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 10.6+ KB

# %%
data.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     185.000000       185.000000     187.000000
# mean      105.124324        83.221622      50.165775
# std       100.524714        89.142958      80.358868
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        60.000000       9.000000
# 75%       185.000000       132.000000      60.500000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    192.000000
# mean                       4.741667
# std                        3.767654
# min                        0.000000
# 25%                        1.300000
# 50%                        4.250000
# 75%                        7.200000
# max                       14.400000

# %%
data.isna().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
num_cols=data[['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol']]
num_cols.isna().sum()
# Out:
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# dtype: int64

# %%
#Simple imputer
from sklearn.impute import SimpleImputer
#creating instance of package simple imputer od sk learn library
imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
#fit numerical data into imputer
imputer=imputer.fit(num_cols)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2275c52a6a5f> in <module>
#       4 imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
#       5 #fit numerical data into imputer
# ----> 6 imputer=imputer.fit(num_cols)
#
# NameError: name 'num_cols' is not defined

# %%
num_cols=imputer.transform(num_cols)
type(num_cols)
num_cols
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [8.90000000e+01, 1.32000000e+02, 5.40000000e+01, 4.90000000e+00],
#        [2.50000000e+01, 0.00000000e+00, 1.40000000e+01, 7.00000000e-01],
#        [2.45000000e+02, 1.38000000e+02, 3.12000000e+02, 1.24000000e+01],
#        [2.17000000e+02, 5.70000000e+01, 4.50000000e+01, 5.90000000e+00],
#        [1.02000000e+02, 1.28000000e+02, 4.50000000e+01, 4.90000000e+00],
#        [1.05124324e+02, 2.50000000e+01, 2.21000000e+02, 8.30000000e+00],
#        [2.10000000e+01, 1.79000000e+02, 1.10000000e+01, 3.80000000e+00],
#        [2.61000000e+02, 7.20000000e+01, 2.12000000e+02, 1.04000000e+01],
#        [2.79000000e+02, 7.50000000e+01, 1.91000000e+02, 9.70000000e+00],
#        [2.10000000e+01, 4.60000000e+01, 5.00000000e+00, 1.30000000e+00],
#        [1.22000000e+02, 1.76000000e+02, 5.10000000e+01, 6.30000000e+00],
#        [4.20000000e+01, 6.30000000e+01, 7.00000000e+00, 2.00000000e+00],
# ...

# %%
num_cols=pd.DataFrame(num_cols,columns=[['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol']])

# %%
num_cols
# Out:
#     beer_servings spirit_servings wine_servings total_litres_of_pure_alcohol
# 0        0.000000             0.0           0.0                          0.0
# 1       89.000000           132.0          54.0                          4.9
# 2       25.000000             0.0          14.0                          0.7
# 3      245.000000           138.0         312.0                         12.4
# 4      217.000000            57.0          45.0                          5.9
# ..            ...             ...           ...                          ...
# 188    105.124324           100.0           3.0                          7.7
# 189    111.000000             2.0           1.0                          2.0
# 190      6.000000             0.0           0.0                          0.1
# 191     32.000000            19.0           4.0                          2.5
# 192     64.000000            18.0           4.0                          4.7
#
# [193 rows x 4 columns]

# %%
num_cols.isna().sum()
# Out:
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# dtype: int64

# %%
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela            NaN            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
data.drop(['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol'],inplace=True,axis=1)
data.head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
data=pd.concat([num_cols,data],axis=1)
data.head()
# Out:
#    (beer_servings,)  (spirit_servings,)  (wine_servings,)  \
# 0               0.0                 0.0               0.0
# 1              89.0               132.0              54.0
# 2              25.0                 0.0              14.0
# 3             245.0               138.0             312.0
# 4             217.0                57.0              45.0
#
#    (total_litres_of_pure_alcohol,)      country continent
# 0                              0.0  Afghanistan      Asia
# 1                              4.9      Albania    Europe
# 2                              0.7      Algeria    Africa
# 3                             12.4      Andorra    Europe
# 4                              5.9       Angola    Africa

# %%
data.isna().sum()
# Out:
# (beer_servings,)                   0
# (spirit_servings,)                 0
# (wine_servings,)                   0
# (total_litres_of_pure_alcohol,)    0
# country                            0
# continent                          0
# dtype: int64

# %%
#method 2
data2=pd.read_csv('beer-servings.csv',index_col='Unnamed: 0')
data2.isna().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
#use the float type columns only for plotting
freqGraph=data2.select_dtypes(include=['float'])
freqGraph.hist(figsize=(20,15))
plt.show()

# %%
#All the columns are right skewed
data2.columns
# Out:
# Index(['Unnamed: 0', 'country', 'beer_servings', 'spirit_servings',
#        'wine_servings', 'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
data2['beer_servings']=data2['beer_servings'].fillna(data2['beer_servings'].median())
data2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela           76.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
data2.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
for col in ['spirit_servings','wine_servings','total_litres_of_pure_alcohol','beer_servings']:
  data2[col]=data2[col].fillna(data2[col].mean())

# %%
  data2.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
#Outliers
plt.boxplot(data2['beer_servings'])
plt.show()

# %%
#Outliers
plt.boxplot(data2['spirit_servings'])
plt.show()

# %%
Q1=np.percentile(data2['spirit_servings'],25,interpolation='midpoint')
Q2=np.percentile(data2['spirit_servings'],50,interpolation='midpoint')
Q3=np.percentile(data2['spirit_servings'],75,interpolation='midpoint')
print(Q1,Q2,Q3)
# Out:
# 5.0 65.0 128.0

# %%
data2['spirit_servings'].median()
# Out:
# 65.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 123.0

# %%
low_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
print(low_limit)
print(upper_limit)
# Out:
# -179.5
# 312.5

# %%
outlier_list=[]
for i in data2['spirit_servings']:
  if (i>upper_limit) or (i<low_limit):
    outlier_list.append(i)

# %%
outlier_list
# Out:
# [373.0, 438.0, 326.0, 326.0, 315.0]

# %%
ind=data2['spirit_servings']>upper_limit
data2.loc[ind].index
# Out:
# Int64Index([15, 68, 73, 141, 144], dtype='int64')

# %%
data2.drop([15, 68, 73, 141, 144])
data2
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela           76.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
#Assignment
#Outliers of wine servings
plt.boxplot(data2['wine_servings'])
plt.title('Wine servings')
plt.show()

# %%
Q1=np.percentile(data2['wine_servings'],25,interpolation='midpoint')
Q2=np.percentile(data2['wine_servings'],50,interpolation='midpoint')
Q3=np.percentile(data2['wine_servings'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
# Out:
# 1.0
# 9.0
# 59.0

# %%
IQR=Q3-Q1
IQR
# Out:
# 58.0

# %%
low_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
print(low_limit)
print(upper_limit)
# Out:
# -86.0
# 146.0

# %%
ind=data2['wine_servings']>146
data2.loc[ind].index
# Out:
# Int64Index([  3,   6,   8,   9,  16,  35,  42,  48,  55,  61,  64,  65,  67,
#              75,  81,  83,  99, 120, 121, 136, 140, 156, 165, 166, 182, 185],
#            dtype='int64')

# %%
#Outliers of wine servings
plt.boxplot(data2['total_litres_of_pure_alcohol'])
plt.title('Total litres of pure alocohol')
plt.show()

# %% [markdown]
# No Outliers for total_litres_of_pure_alcohol

# %%
##Session for Preprocessing -Merge,join
data
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela            NaN            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
data.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %% [markdown]
# For filling missing value

# %%
for col in ['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol']:
  data[col]=data[col].fillna(data[col]).median()

# %%
data.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
##Encoding
data.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
#As apart of encoding droping country column 
data.drop('country',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-4ff62488ccd7> in <module>
#       1 #As apart of encoding droping country column
# ----> 2 data.drop('country',axis=1,inplace=True)
#       3
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
#Label encoding
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
label_enc=LabelEncoder()
#label encode continent
data['continent']=label_enc.fit_transform(data['continent'])

# %%
data.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0           76.0             60.0            9.0
# 1           76.0             60.0            9.0
# 2           76.0             60.0            9.0
# 3           76.0             60.0            9.0
# 4           76.0             60.0            9.0
#
#    total_litres_of_pure_alcohol  continent
# 0                          4.25          1
# 1                          4.25          2
# 2                          4.25          0
# 3                          4.25          2
# 4                          4.25          0

# %%
data.dtypes
# Out:
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                         int64
# dtype: object

# %%
#Splitting to target and features
#X stores independent variables,features
X=data.drop(['total_litres_of_pure_alcohol'],axis=1)
#Y has only target variable
Y=data['total_litres_of_pure_alcohol']
X
# Out:
#      beer_servings  spirit_servings  wine_servings  continent
# 0             76.0             60.0            9.0          1
# 1             76.0             60.0            9.0          2
# 2             76.0             60.0            9.0          0
# 3             76.0             60.0            9.0          2
# 4             76.0             60.0            9.0          0
# ..             ...              ...            ...        ...
# 188           76.0             60.0            9.0          5
# 189           76.0             60.0            9.0          1
# 190           76.0             60.0            9.0          1
# 191           76.0             60.0            9.0          0
# 192           76.0             60.0            9.0          0
#
# [193 rows x 4 columns]

# %%
Y
# Out:
# 0      4.25
# 1      4.25
# 2      4.25
# 3      4.25
# 4      4.25
#        ...
# 188    4.25
# 189    4.25
# 190    4.25
# 191    4.25
# 192    4.25
# Name: total_litres_of_pure_alcohol, Length: 193, dtype: float64

# %%
#Dropping continent
X1=X.drop('continent',axis=1)

# %%
X1
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0             76.0             60.0            9.0
# 1             76.0             60.0            9.0
# 2             76.0             60.0            9.0
# 3             76.0             60.0            9.0
# 4             76.0             60.0            9.0
# ..             ...              ...            ...
# 188           76.0             60.0            9.0
# 189           76.0             60.0            9.0
# 190           76.0             60.0            9.0
# 191           76.0             60.0            9.0
# 192           76.0             60.0            9.0
#
# [193 rows x 3 columns]

# %%
#Normalising X1
X1=preprocessing.normalize(X1)

# %%
type(X1)
# Out:
# numpy.ndarray

# %%
col=['beer_servings', 'spirit_servings', 'wine_servings']

# %%
X1=pd.DataFrame(X1,columns=col)
X1
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0         0.781514         0.616985       0.092548
# 1         0.781514         0.616985       0.092548
# 2         0.781514         0.616985       0.092548
# 3         0.781514         0.616985       0.092548
# 4         0.781514         0.616985       0.092548
# ..             ...              ...            ...
# 188       0.781514         0.616985       0.092548
# 189       0.781514         0.616985       0.092548
# 190       0.781514         0.616985       0.092548
# 191       0.781514         0.616985       0.092548
# 192       0.781514         0.616985       0.092548
#
# [193 rows x 3 columns]

# %%
X1.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings
# count     193.000000     1.930000e+02   1.930000e+02
# mean        0.781514     6.169849e-01   9.254774e-02
# std         0.000000     1.113110e-16   1.391388e-17
# min         0.781514     6.169849e-01   9.254774e-02
# 25%         0.781514     6.169849e-01   9.254774e-02
# 50%         0.781514     6.169849e-01   9.254774e-02
# 75%         0.781514     6.169849e-01   9.254774e-02
# max         0.781514     6.169849e-01   9.254774e-02

# %%
X.drop(['beer_servings', 'spirit_servings', 'wine_servings'],axis=1,inplace=True)

# %%
X
# Out:
#      continent
# 0            1
# 1            2
# 2            0
# 3            2
# 4            0
# ..         ...
# 188          5
# 189          1
# 190          1
# 191          0
# 192          0
#
# [193 rows x 1 columns]

# %%
X=pd.concat([X,X1],axis=1)

# %%
X
# Out:
#      continent  beer_servings  spirit_servings  wine_servings
# 0            1       0.781514         0.616985       0.092548
# 1            2       0.781514         0.616985       0.092548
# 2            0       0.781514         0.616985       0.092548
# 3            2       0.781514         0.616985       0.092548
# 4            0       0.781514         0.616985       0.092548
# ..         ...            ...              ...            ...
# 188          5       0.781514         0.616985       0.092548
# 189          1       0.781514         0.616985       0.092548
# 190          1       0.781514         0.616985       0.092548
# 191          0       0.781514         0.616985       0.092548
# 192          0       0.781514         0.616985       0.092548
#
# [193 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=42,test_size=0.2)

# %%
#building model
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(X_train,Y_train)
predict=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
print('MSE=',mean_squared_error(Y_test,predict))
# Out:
# MSE= 0.0

# %%
#Correlation
corrmatrix=data.corr()
plt.subplots(figsize=(20,8))
sns.heatmap(corrmatrix,annot=True,vmax=0.9,linewidth=0.2,cmap='Greens')

# %%
X=data.drop(['spirit_servings','wine_servings'],axis=1)

# %%
X
# Out:
#      beer_servings  total_litres_of_pure_alcohol  continent
# 0             76.0                          4.25          1
# 1             76.0                          4.25          2
# 2             76.0                          4.25          0
# 3             76.0                          4.25          2
# 4             76.0                          4.25          0
# ..             ...                           ...        ...
# 188           76.0                          4.25          5
# 189           76.0                          4.25          1
# 190           76.0                          4.25          1
# 191           76.0                          4.25          0
# 192           76.0                          4.25          0
#
# [193 rows x 3 columns]

# %%
datas=pd.read_csv('diamonds_new.csv')

# %%
datas.head()
# Out:
#    carat      cut color clarity  table     x     y     z  price_new
# 0   0.23    Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1   0.21  Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2   0.23     Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3   0.29  Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4   0.31     Good     J     SI2   58.0  4.34  4.35  2.75      167.5

# %%
datas.isna().sum()
# Out:
# carat        99
# cut           0
# color        56
# clarity       0
# table        63
# x             0
# y             0
# z             0
# price_new     0
# dtype: int64

# %%
datas.dtypes
# Out:
# carat        float64
# cut           object
# color         object
# clarity       object
# table        float64
# x            float64
# y            float64
# z            float64
# price_new    float64
# dtype: object

# %%
datas.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'table', 'x', 'y', 'z',
#        'price_new'],
#       dtype='object')

# %%
datas[['cut', 'color', 'clarity']]
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53940 rows x 3 columns]

# %%
datas.describe()
# Out:
#               carat         table             x             y             z  \
# count  53841.000000  53877.000000  53940.000000  53940.000000  53940.000000
# mean       0.798120     57.457719      5.731157      5.734526      3.539635
# std        0.474428      2.235742      1.121761      1.142135      0.703869
# min        0.200000     43.000000      0.000000      0.000000      0.000000
# 25%        0.400000     56.000000      4.710000      4.720000      2.910000
# 50%        0.700000     57.000000      5.700000      5.710000      3.530000
# 75%        1.040000     59.000000      6.540000      6.540000      4.040000
# max        5.010000     95.000000     10.740000     58.900000     31.800000
#
#           price_new
# count  53940.000000
# mean    1966.399861
# std     1994.719869
# min      163.000000
# 25%      475.000000
# 50%     1200.500000
# 75%     2662.125000
# max     9411.500000

# %%
zero_index=datas[(datas['x']==0) | (datas['y']==0) | (datas['z']==0)].index
zero_index
# Out:
# Int64Index([11182, 11963, 15951, 24520, 26243, 27429, 49556, 49557], dtype='int64')

# %%
datas1=datas.drop(zero_index)

# %%
datas1
# Out:
#        carat        cut color clarity  table     x     y     z  price_new
# 0       0.23      Ideal     E     SI2   55.0  3.95  3.98  2.43      163.0
# 1       0.21    Premium     E     SI1   61.0  3.89  3.84  2.31      163.0
# 2       0.23       Good     E     VS1   65.0  4.05  4.07  2.31      163.5
# 3       0.29    Premium     I     VS2   58.0  4.20  4.23  2.63      167.0
# 4       0.31       Good     J     SI2   58.0  4.34  4.35  2.75      167.5
# ...      ...        ...   ...     ...    ...   ...   ...   ...        ...
# 53935   0.72      Ideal     D     SI1   57.0  5.75  5.76  3.50     1378.5
# 53936   0.72       Good     D     SI1   55.0  5.69  5.75  3.61     1378.5
# 53937   0.70  Very Good     D     SI1   60.0  5.66  5.68  3.56     1378.5
# 53938   0.86    Premium     H     SI2   58.0  6.15  6.12  3.74     1378.5
# 53939   0.75      Ideal     D     SI2   55.0  5.83  5.87  3.64     1378.5
#
# [53932 rows x 9 columns]

# %%
datas1.describe()
# Out:
#               carat         table             x             y            z  \
# count  53833.000000  53869.000000  53932.000000  53932.000000  53932.00000
# mean       0.798059     57.457564      5.732007      5.735254      3.54016
# std        0.474403      2.235315      1.119670      1.140343      0.70260
# min        0.200000     43.000000      3.730000      3.680000      1.07000
# 25%        0.400000     56.000000      4.710000      4.720000      2.91000
# 50%        0.700000     57.000000      5.700000      5.710000      3.53000
# 75%        1.040000     59.000000      6.540000      6.540000      4.04000
# max        5.010000     95.000000     10.740000     58.900000     31.80000
#
#           price_new
# count  53932.000000
# mean    1966.068039
# std     1994.367418
# min      163.000000
# 25%      474.875000
# 50%     1200.500000
# 75%     2662.000000
# max     9411.500000

# %%
plt.boxplot(datas1['x'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7b027f4990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7aff56cb90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7aff5cb490>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7aff53d8d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7aff53da50>],
#  'means': []}

# %%
plt.boxplot(datas1['y'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7aff4b5e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7aff4ba910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7aff4b58d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7aff4c2410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7aff4c2950>],
#  'means': []}

# %%
sns.pairplot(datas1[['x','y','z']])

# %%
datas1[datas1['y']>30].index
# Out:
# Int64Index([24067, 49189], dtype='int64')

# %%
datas1[datas1['z']>30].index
# Out:
# Int64Index([48410], dtype='int64')

# %%
datas2=datas1.drop([24067, 49189,48410])
